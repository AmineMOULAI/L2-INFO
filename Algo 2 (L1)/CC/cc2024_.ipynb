# %% [markdown]
# Ne pas dégrafer les feuilles.
# Durée : 2 heures. Aucun document autorisé.
# Modalités : Répondre uniquement dans les zones de ﬁfeuilles à petits carreauxﬂ. La qualité de la rédaction
# sera prise en compte dans la notation. Les questions avec (
# ?
# ) sont de niveau ﬁObjectif 20ﬂ. Un barème est
# indiqué à droite de chaque question. La note nale sur 20 est proportionnellement déduite de ce barème.
# Exercice 1.
# Pile en tableau et application (15 points)
# /15
# Dans cet exercice, on met en œuvre une pile en utilisant un tableau, puis on applique cette pile à l'évaluation
# d'une expression arithmétique en notation (dite) post-xée (ou polonaise inversée).
# On a déjà présenté et utilisé la notion de
# pile
# Œ par exemple la pile des appels récursifs. Une pile est une
# structure de données qui permet de stocker des valeurs. Elle est dite LIFO :
# last in, rst out
# .
# Le
# sommet
# de la pile est à la fois la dernière valeur ajoutée à la pile, et la première valeur a en être retirée.
# Les valeurs stockées dans une pile se manipulent
# uniquement
# avec deux traitements :
# Œ
#  empiler : on ajoute une nouvelle valeur à la pile et cette valeur devient le sommet de la pile.
# Œ
#  dépiler : on retire la valeur sommet de pile.
# Une pile qui contient aucune valeur est dite
# vide
# .
# En pratique, une pile d'assiettes est un bon exemple de pile.
# En python, un tableau est une liste (
# list
# ). On
# n'utilisera pas
# les fonctions
# .append()
# et
# .pop()
# (qui corres-
# pondent à ﬁempiler ﬂ et ﬁdépiler ﬂ), ni aucune des fonctions méthodes des
# list
# . On considère un
# vrai
# tableau
# comme déni en cours.
# Voilà comment une pile est mise en œuvre avec un tableau.
# Œ
#  Un tableau de longueur
# n+1
# dénit une liste qui peut stocker au plus
# n
# valeurs.
# Œ
#  Ce nombre
# n
# sera appelé ici
# longueur de la pile
# .
# Œ
#  La première valeur du tableau Œ celle d'indice 0 Œ contient l'indice du sommet de la pile, c-a-d. une
# valeur entre 1 et
# n
# .
# Œ
#  A l'
# initialisation
# , la pile est
# vide
# . La valeur d'indice 0 (ie. l'indice du sommet de pile) vaut 0 et les
# n
# suivantes sont arbitraires.
# Œ
#  Tant que le tableau n'est pas plein,
# empiler une valeur
# incrémente l'indice du sommet de pile et stocke
# cette valeur à l'indice du sommet .
# Œ
#  Tant que la pile n'est pas vide,
# dépiler
# retourne la valeur du sommet de pile et décrémente l'indice du
# sommet.
# Œ
#  dépiler une pile vide et empiler sur une pile pleine déclenchent l' ﬁerreur ﬂ python
# Assertion Error
# .
# Le schéma ci-contre illustre l'effet des traitements successifs suivants.
# 1.
#  initialiser
# p6
# , pile de longueur 6
# 2.
#  empiler l'entier 7 sur la pile
# p6
# 3.
#  empiler l'entier 4 sur la pile
# p6
# 4.
#  dépiler la pile
# p6
# dans
# v
# 1
#
#
# Important.
# Œ
#  La signature de chaque fonction sera complète Œ seul le docstring n'est pas demandé.
# Œ
#  Même si il est mis en œuvre avec un ta bleau, le paramètre formel
# pile
# n'a pas besoin d'être suivi de
# l'habituel paramètre
# taille
# d'un tableau.
# (
# ?
# )
#  Chaque fonction doit être accompagnée de quelques tests unitaires pertinents.
# 1.
#  Ecrire la fonction
# init_pile()
# qui créé et retourne une pile d'entiers de longueur
# n
# (c-a-d. qui peut
# stocker
# n
# valeurs).
# /1
# 2.
#  Ecrire la fonction
# est_vide()
# qui vérie si une pile est vide ou non.
# /1
# 3.
#  Ecrire une fonction
# empiler()
# qui empile une valeur
# v
# sur une pile
# p
# de longueur
# n
# . Cette fonction
# modie
# p
# et ne retourne aucune valeur.
# /1
# 2
#
#
# 4.
#  Ecrire une fonction
# depiler()
# qui dépile et retourne la valeur
# v
# sommet de la pile
# p
# de longueur
# n
# .
# /1
# 5.
#  Ecrire la fonction
# afficher()
# qui afche les valeurs d'une pile de longueur
# n
# . Seules les valeurs de la
# pile sont afchées. Cet afchage s'effectue verticalement et du haut vers le bas en partant du sommet
# de la pile.
# /1
# Application.
# Une expression arithmétique s'écrit de plusieurs façons dont celle dite
# postxée
# (ou
# polo-
# naise inversée
# ). Par exemple,
# (
# E
# ) : (2 + 5)
#
# p
# 4
#
# (5 + 3)
# 2
# s'écrit en notation
# postxée
# :
# (
# E
# ) :
# 2 5 + 4 5 3 + 2 **
#
# p
#
# ou plus simplement en notant RC (racine carrée) à la place de
# p
# :
# 3
#
#
# (
# E
# ) :
# 2 5 + 4 5 3 + 2 **
#
# RC
#
# Calculer une expression postxée s'effectue simplement à l'aide d'une pile comme suit.
# Œ
#  La pile est vide avant l'évaluation de l'expression.
# Œ
#  Si on rencontre :
# -
#  un nombre : on l'empile ;
# -
#  une opération
# +
# ;
#
# ;
#
# ; =;
#
# : on dépile deux fois (le sommet et le ﬁsous-sommetﬂ), on effectue le
# calcul
# sous-sommet opération sommet
# , on empile le résultat ;
# -
#  une fonction (RC) : on dépile (le sommet), on calcule la fonction pour la valeur du sommet, on
# empile le résultat.
# 6.
#  Que contient la pile à la n de l'évaluation de l'expression ? Justier votre réponse.
# /1
# 7.
#  Comment choisir une longueur de pile adaptée à l'évaluation d'une expression ? Justier votre ré-
# ponse.
# /1
# 8.
#  En partant d'une pile vide de longueur arbitraire
# l
# (par exemple
# l=12
# ), expliciter la suite d'appels et
# chaque modication de la pile lors du calcul de l'expression (E).
# /3
# 4
#
#
# Généralisation.
# On va écrire une fonction
# eval
# qui calcule et retourne la valeur d'une expression arith-
# métique postxée. Pour cela, l'expression postxée est représentée par une liste de valeurs numériques,
# de caractères ou de chaines de caractères.
# Œ
#  Les nombres sont notés par leur valeur :
# 1
# ,
# 3.5
# , . . . ;
# Œ
#  les opérateurs sont notés par la
# str
# de leur symbole :
# "+", "-", "
# *
# ", "/", "
# **
# "
# ;
# Œ
#  La fonction
# p
# est notée par la
# str "RC"
# .
# Dans la liste qui représente une expression, les valeurs sont ordonnées comme dans l'expression lue de
# la gauche vers la droite. Ainsi, 2 est la première valeur de la liste qui représente l'expression
# (
# E
# ) :
# 2 5 + 4 5 3 + 2 **
#
# RC
#
# 9.
#  Expliciter la liste qui représente l'expression (E).
# /1
# On suppose l'existence des fonctions de signatures suivantes.
# #
#  l e
#  s y m b o l e
#  " | "
#  e s t
#  u n
#  "
#  o u
#  "
# d e f
#  t t y p e ( v :
#  s t r
#  |
#  i n t
#  |
#  f l o a t
#  ) >
#  i n t
#  :
# ' ' '
#  r e t o u r n e
#  :
#
#  0
#  s i
#  v
#  e s t
#  u n
#  n o m b r e
#  (
#  i n t
#  o u
#  f l o a t
#  )
#  ,
#
#  1
#  s i
#  v
#  e s t
#  u n
#  o p e r a t e u r
#  (
#  n o t e
#  a v e c
#  s t r
#  )
#  ,
#
#  2
#  s i
#  v
#  e s t
#  u n e
#  f o n c t i o n
#  (
#  n o t e e
#  a v e c
#  s t r
#  )
# ' ' '
# d e f
#  c a l c _ o p ( a :
#  i n t
#  |
#  f l o a t
#  , o p :
#  s t r
#  , b :
#  i n t
#  |
#  f l o a t
#  ) >
#  i n t
#  |
#  f l o a t
#  :
# ' ' '
#  c a l c u l e
#  a
#  o p
#  b
#  e t
#  r e t o u r n e
#  c e
#  r e s u l t a t
#  ' ' '
# a s s e r t o p
#  i n
#  (
#  "
#  +
#  "
#  ,
#  "
#
#  "
#  ,
#  "
# *
# "
#  ,
#  "
#  /
#  "
#  ,
#  "
# * *
# "
#  )
# d e f
#  c a l c _ f ( f :
#  s t r
#  , a :
#  i n t
#  |
#  f l o a t
#  ) >
#  i n t
#  |
#  f l o a t
#  :
# ' ' '
#  c a l c u l e
#  f
#  (
#  a
#  )
#  e t
#  r e t o u r n e
#  c e
#  r e s u l t a t
#  ' ' '
# a s s e r t f ==
#  "
#  RC
#  "
# 5
#
#
# 10.
#  (
# ?
# ) Ecrire la fonction
# eval()
# qui évalue une expression postxée représentée par une liste.
# eval()
# retourne le résultat de l'évaluation.
# /3
# 11.
#  Evaluer (E) avec
# eval()
# .
# /1
# 6
#
#
# Exercice 2.
# Arbre binaire : parcours et application (12 points)
# /12
# Un
# arbre binaire
# non vide est formé d'un noeud, sa
# racine
# , et de deux
# sous-arbres
# binaires, l'un appelé
# le ls
# gauche
# , l'autre
# le ls droit
# (ou sous-arbre gauche et sous-arbre droit).
# Chaque noeud stocke une information, appelée
# sa valeur
# (ou son contenu).
# L'arbre binaire
# vide
# ne contient aucun sommet.
# Un arbre non vide est donc entièrement décrit par le triplet (ls gauche, valeur de la racine, ls droit).
# On note
# ab5
# l'arbre binaire de la gure suivante où la valeur de chaque noeud est un entier.
# On suppose les fonctions suivantes dénies sur un arbre binaire (abrégé par ﬁabﬂ)
# x
# . Dans les paramètres
# de fonction, on note
# ab
# le type ﬁabﬂ. Des assertions illustrent l'application de ces fonctions à l'arbre binaire
# exemple
# ab5
# .
# #
#  t y p e
#  a r b r e
#  b i n a i r e
#  d e
#  v a l e u r s
#  e n t i e r e s
# a b =
#  l i s t
#  [
#  i n t
#  ]
# d e f
#  e s t _ v i d e ( x : a b ) >
#  b o o l
#  :
# ' ' '
#  v e r i f i e
#  s i
#  l
#  '
#  a b
#  x
#  e s t
#  v i d e
#  o u
#  n o n
#  ' ' '
# d e f
#  v a l ( x : a b ) >
#  i n t
#  :
# ' ' '
#  r e t o u r n e
#  l a
#  v a l e u r
#  d e
#  l a
#  r a c i n e
#  d e
#  l
#  '
#  a b
#  n o n
#  v i d e
#  x
#  ' ' '
# a s s e r t
#  n o t
#  ( e s t _ v i d e ( x ) )
# d e f
#  f i l s G ( x : a b ) > a b | None :
# ' ' '
#  r e t o u r n e
#  l e
#  s o u s
#
#  a r b r e
#  g a u c h e
#  d e
#  l
#  '
#  a b
#  n o n
#  v i d e
#  x
#  ' ' '
# a s s e r t
#  n o t
#  ( e s t _ v i d e ( x ) )
# d e f
#  f i l s D ( x : a b ) > a b | None :
# ' ' '
#  r e t o u r n e
#  l e
#  s o u s
#
#  a r b r e
#  d r o i t
#  d e
#  l
#  '
#  a b
#  n o n
#  v i d e
#  x
#  .
#  ' ' '
# a s s e r t
#  n o t
#  ( e s t _ v i d e ( x ) )
# a b 5 = . . .
#  #
#  d e f i n i
#  comme
#  s u r
#  l a
#  f i g u r e
# a s s e r t e s t _ v i d e ( a b 5 ) == F a l s e
# a s s e r t v a l ( a b 5 ) == 5
# a s s e r t v a l ( f i l s G ( a b 5 ) ) == 3
# a s s e r t v a l ( f i l s D ( a b 5 ) ) == 6
# 7
#
#
# 1.
#  On code l'algorithme
# ps
# par la fonction récursive suivante.
# d e f
#  p s ( x : a b ) > None :
# i f
#  n o t
#  ( e s t _ v i d e ( x ) ) :
# p s ( f i l s G ( x ) )
# p s ( f i l s D ( x ) )
# p r i n t
#  ( v a l ( x ) , e n d =
#  "
#  ,
#  "
#  )
# On simpliera l'écriture des réponses aux questions suivantes en identiant tout sous-arbre non vide
# de
# ab5
# à la valeur de sa racine (toutes ces valeurs sont différentes). Par exemple,
# ps(ab5)
# pourra aussi
# être noté
# ps5
# et
# ps(FilsG(ab5))
# pourra aussi être noté
# ps3
# car 3 est la valeur de la racine du ls
# gauche de
# pp(ab5)
# .
# (a)
#  Donner l'arbre des appels de
# ps(ab5)
# .
# /1
# (b)
#  Donner l'évolution de la pile des appels de
# ps(ab5)
# .
# /1
# (c)
#  Donner les afchages produits par l'exécution de
# ps(ab5)
# .
# /1
# 8
#
#
# 2.
#  On code l'algorithme
# pi
# par la fonction récursive suivante.
# d e f
#  p i ( x : a b ) > None :
# i f
#  n o t
#  ( e s t _ v i d e ( x ) ) :
# p i ( f i l s G ( x ) )
# p r i n t
#  ( v a l ( x ) , e n d =
#  "
#  ,
#  "
#  )
# p i ( f i l s D ( x ) )
# On appliquera des simplications d'écritures similaires à la question précédente (comme par exemple
# pi5
# ou
# pi3
# ).
# (a)
#  Donner l'arbre des appels de
# pi(ab5)
# .
# /1
# (b)
#  Donner l'évolution de la pile des appels de
# pi(ab5)
# .
# /1
# (c)
#  Donner les afchages produits par l'exécution de
# pi(ab5)
# .
# /1
# 9
#
#
# 3.
#  Ecrire la fonction récursive
# maximum()
# qui calcule et retourne la valeur maximale d'un arbre binaire
# non vide (à valeurs entières). Par exemple, cette fonction calcule et retourne
# 9
# pour
# ab5
# .
# /1
# 4.
#  Ecrire la fonction récursive
# nbNoeuds()
# qui calcule et retourne le nombre de noeuds d'un arbre binaire.
# Par exemple, cette fonction calcule et retourne
# 10
# pour
# ab5
# .
# /1
# 10
#
#
# Application.
# Un arbre binaire peut contenir des valeurs de types différents. L'arbre binaire
# abe
# suivant
# suivant représente l'expression arithmétique :
# (
# E
# 0
# ) : ((
# a
# +
# b
# )
#
# (
# c
#
# d
# ))
# =
# (
# e
# +
# f
# )
# :
# Comme dans l'exercice 1, les valeurs de
# abe
# sont des
# str
# , des
# int
# ou des
# float
# .
# Votre réponse à la question suivante peut reprendre des traitements de l'exercice 1 et supposer que les
# opérandes
# a
# ,
# b
# , . . .
# f
# sont des entiers ou des ottants.
# 5.
#  (
# ?
# ) Ecrire l'algorithme qui évalue (E') à partir de
# abe
# .
# /4
# 11
#
#
# 12
